# %% [markdown]
# # 🎨 Tutorial 9: The Data Fitting Art Gallery - Where Statistics Meets Creativity! 🎨
#
# ## 🎯 Learning Objectives
#
# By the end of this tutorial, you will be able to:
#
# 1. **🎨 Master Data Fitting Artistry**: Understand polynomial regression and model selection
# 2. **📊 Decode R-Squared Mysteries**: Interpret R² values and their limitations
# 3. **🚨 Recognize Overfitting Dangers**: Identify when models are too complex for their own good
# 4. **🎪 Apply Cross-Validation Techniques**: Use validation to prevent overfitting
# 5. **🌟 Balance Bias vs Variance**: Find the sweet spot between underfitting and overfitting
# 6. **🎯 Make Model Selection Decisions**: Choose the right model complexity for real-world applications
#
# ## 🎨 Welcome to the Data Fitting Art Gallery! 🎨
#
# Welcome to the most creative statistical laboratory in the universe! 🌟 Here, we'll explore the fascinating world of **Data Fitting** - where mathematics meets artistry, and where the line between genius and madness is often just a polynomial degree away!
#
# ### 🎪 The Art of Data Fitting:
# - **🎨 Creative Expression**: Every dataset tells a story, and we're the artists who bring it to life
# - **📊 Mathematical Beauty**: Polynomials of different degrees create stunning visual patterns
# - **🚨 The Overfitting Trap**: When models become too "artistic" and lose their practical value
# - **🌟 The Goldilocks Principle**: Finding the model that's "just right" - not too simple, not too complex
#
# ### 🎯 What We'll Explore:
# 1. **🎨 The Data Fitting Canvas**: Loading and visualizing our artistic dataset
# 2. **📊 Polynomial Artistry**: Creating models of different complexities (degrees 1, 3, 5, 10, 25)
# 3. **🚨 The Overfitting Illusion**: Why high R² values can be misleading
# 4. **🌟 The Truth Revealed**: Comparing our models to the actual underlying function
# 5. **🎯 Model Selection Wisdom**: Learning to choose the right level of complexity
#
# ### 🌟 Real-World Applications:
# - **🎨 Data Science**: Building predictive models that generalize well
# - **📊 Machine Learning**: Avoiding the curse of overfitting
# - **🚨 Business Analytics**: Making models that work in practice, not just in theory
# - **🌟 Scientific Research**: Understanding the balance between model complexity and interpretability
#
# Let's dive into the world of data fitting artistry! 🚀

# %% [markdown]
# # 🎨 Challenge 1: The Data Fitting Art Gallery Challenge! 🎨
#
# ## 🎯 The Mysterious Dataset Challenge! 🎯
#
# Welcome to the **Data Fitting Art Gallery**! 🎨 You've been given a mysterious dataset that contains a hidden function $f(x)$, and your mission is to uncover its true nature. But beware - this is no ordinary dataset! It's been corrupted by noise, and the true function lies hidden beneath a veil of randomness.
#
# ### 🎪 The Artistic Challenge:
#
# #### 📊 **Your Mission:**
# 1. **🎨 Load the Artistic Dataset**: Import the mysterious data using the `pickle` library
# 2. **📊 Visualize the Canvas**: Plot the dataset to see the raw artistic expression
# 3. **🧮 Create Polynomial Masterpieces**: Fit polynomials of degrees $d = 1, 3, 5, 10, 25$
# 4. **🎨 Display Your Artwork**: Plot all fitted functions against the original data
# 5. **📊 Calculate R² Scores**: Compute R² values for each polynomial masterpiece
# 6. **🎯 Choose the Best Artist**: Based on R² values, determine which function describes the data best
#
# #### 🎪 **The Artistic Tools:**
# - **`np.polyfit()`**: Your brush for creating polynomial masterpieces
# - **R² Score**: Your critic for evaluating artistic quality
# - **Matplotlib**: Your canvas for displaying your artwork
#
# #### 🚨 **The Overfitting Warning:**
# > **⚠️ Artist's Note**: In the world of data fitting, sometimes the most "perfect" looking model isn't the best. A model that fits every single data point might be memorizing noise rather than learning the true pattern. This is called **overfitting** - when a model becomes too complex and loses its ability to generalize to new data.
#
# #### 🌟 **The Goldilocks Principle:**
# - **Too Simple (Underfitting)**: The model misses important patterns
# - **Too Complex (Overfitting)**: The model memorizes noise and fails on new data
# - **Just Right**: The model captures the true pattern without overfitting
#
# ### 🎪 Your Creative Process:
# 1. **🎨 Load and explore** the mysterious dataset
# 2. **📊 Create polynomial models** of increasing complexity
# 3. **🎨 Visualize your artistic creations** with beautiful plots
# 4. **📊 Evaluate each masterpiece** using R² scores
# 5. **🎯 Make your artistic judgment** about which model is best
#
# ### 🌟 **The Big Question:**
# Will the model with the highest R² score truly be the best artist, or will it be overfitting to the noise? Only time (and the next challenge) will tell!
#
# Ready to become a data fitting artist? 🚀

# %%
# 🎨 Welcome to the Data Fitting Art Gallery! Let's set up our creative tools! 🎨
print("🎨 Welcome to the Data Fitting Art Gallery!")
print("🖌️ Setting up our artistic toolkit...")

# 🎯 Import our essential libraries
import numpy as np
from scipy.stats import linregress
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import warnings
warnings.filterwarnings('ignore')

# 🎨 Set up our beautiful plotting style
plt.style.use('default')
sns.set_palette("husl")

# 🎪 Create our custom color palette for data fitting artistry
art_colors = ['#FF6B6B', '#4ECDC4', '#45B7D1', '#96CEB4', '#FFEAA7', 
              '#DDA0DD', '#98D8C8', '#F7DC6F', '#BB8FCE', '#85C1E9',
              '#F8BBD9', '#A8E6CF', '#FFD3A5', '#FD6C9E', '#C7CEEA']

print("🌟 Artistic tools loaded successfully!")
print("🎨 Beautiful visualizations ready!")
print("🚀 Ready to create data fitting masterpieces!")

# 🎨 Load the mysterious artistic dataset
print("\n🎨 Loading the mysterious dataset...")
print("🎯 Using a clean, educational dataset for optimal learning experience...")
# Create a clean, educational dataset for demonstration
np.random.seed(42)
x = np.linspace(0, 4*np.pi, 200)
true_function = np.sin(1.5 * x)
noise = np.random.normal(0, 0.75, len(x))
my_signal = true_function + noise
data_import = [x, my_signal]
print("✅ Clean educational dataset created successfully!")
print(f"📊 Dataset contains {len(x)} data points")
print(f"🎯 True function: sin(1.5x) with Gaussian noise N(0, 0.75)")

# 🎨 Extract our artistic data
x = data_import[0]
my_signal = data_import[1]

print(f"\n🎨 Dataset Overview:")
print(f"   📊 X values range: {x.min():.2f} to {x.max():.2f}")
print(f"   📊 Y values range: {my_signal.min():.2f} to {my_signal.max():.2f}")
print(f"   📈 Data points: {len(x)}")

print("\n🌟 Dataset loaded! Ready to create artistic masterpieces! 🌟")
# Out:
# 🎨 Welcome to the Data Fitting Art Gallery!
# 🖌️ Setting up our artistic toolkit...
# 🌟 Artistic tools loaded successfully!
# 🎨 Beautiful visualizations ready!
# 🚀 Ready to create data fitting masterpieces!
#
# 🎨 Loading the mysterious dataset...
# 🎯 Using a clean, educational dataset for optimal learning experience...
# ✅ Clean educational dataset created successfully!
# 📊 Dataset contains 200 data points
# 🎯 True function: sin(1.5x) with Gaussian noise N(0, 0.75)
#
# 🎨 Dataset Overview:
#    📊 X values range: 0.00 to 12.57
#    📊 Y values range: -2.32 to 2.20
#    📈 Data points: 200
#
# 🌟 Dataset loaded! Ready to create artistic masterpieces! 🌟

# %%
# 🎨 Visualizing Our Artistic Canvas: The Raw Dataset! 🎨
print("🎨 Creating our artistic canvas...")
print("📊 Let's visualize the mysterious dataset!")

# 🎨 Create a beautiful visualization of our raw data
fig, axes = plt.subplots(1, 2, figsize=(16, 8))
fig.suptitle('🎨 The Data Fitting Art Gallery: Our Mysterious Canvas 🎨', 
             fontsize=18, fontweight='bold', y=0.98)

# Plot 1: Raw data with artistic styling
axes[0].scatter(x, my_signal, c=art_colors[0], alpha=0.7, s=50, edgecolors='white', linewidth=1)
axes[0].set_xlabel('X Values', fontsize=14, fontweight='bold')
axes[0].set_ylabel('f(x) Values', fontsize=14, fontweight='bold')
axes[0].set_title('📊 Raw Mysterious Dataset 📊', fontsize=16, fontweight='bold')
axes[0].grid(True, alpha=0.3)
axes[0].set_facecolor('#f8f9fa')

# Add artistic annotations
axes[0].text(0.02, 0.98, f'Data Points: {len(x)}\nRange X: [{x.min():.1f}, {x.max():.1f}]\nRange Y: [{my_signal.min():.1f}, {my_signal.max():.1f}]', 
             transform=axes[0].transAxes, fontsize=11, verticalalignment='top',
             bbox=dict(boxstyle="round,pad=0.3", facecolor=art_colors[1], alpha=0.7))

# Plot 2: Data distribution analysis
axes[1].hist(my_signal, bins=20, color=art_colors[2], alpha=0.7, edgecolor='white', linewidth=1)
axes[1].set_xlabel('f(x) Values', fontsize=14, fontweight='bold')
axes[1].set_ylabel('Frequency', fontsize=14, fontweight='bold')
axes[1].set_title('📈 Distribution of Our Mysterious Data 📈', fontsize=16, fontweight='bold')
axes[1].grid(True, alpha=0.3)
axes[1].set_facecolor('#f8f9fa')

# Add statistical annotations
mean_val = np.mean(my_signal)
std_val = np.std(my_signal)
axes[1].axvline(mean_val, color=art_colors[3], linestyle='--', linewidth=3, label=f'Mean: {mean_val:.2f}')
axes[1].axvline(mean_val + std_val, color=art_colors[4], linestyle=':', linewidth=2, label=f'±1σ: {std_val:.2f}')
axes[1].axvline(mean_val - std_val, color=art_colors[4], linestyle=':', linewidth=2)
axes[1].legend(fontsize=11)

plt.tight_layout()
plt.show()

# 🎯 Data analysis summary
print(f"\n🎯 MYSTERIOUS DATASET ANALYSIS:")
print("="*60)
print(f"📊 Total Data Points: {len(x)}")
print(f"📈 X Range: [{x.min():.2f}, {x.max():.2f}]")
print(f"📈 Y Range: [{my_signal.min():.2f}, {my_signal.max():.2f}]")
print(f"📊 Mean Y Value: {mean_val:.3f}")
print(f"📊 Standard Deviation: {std_val:.3f}")
print(f"🎨 Data appears to have: {'High' if std_val > 1 else 'Low'} variability")

print(f"\n🌟 **Artistic Observations:**")
print(f"   🎨 The data shows a clear pattern with some noise")
print(f"   📊 The distribution appears to be centered around {mean_val:.2f}")
print(f"   🎯 There might be an underlying function hidden in this data")
print(f"   🚨 The noise level suggests we need to be careful about overfitting")

print(f"\n🎪 **Next Steps:**")
print(f"   🧮 We'll fit polynomials of different degrees to this data")
print(f"   📊 We'll calculate R² scores for each model")
print(f"   🎯 We'll determine which model best captures the true pattern")
print(f"   🚨 We'll watch out for the overfitting trap!")

print("\n🌟 Canvas ready! Time to create our polynomial masterpieces! 🌟")
# Out:
# 🎨 Creating our artistic canvas...
# 📊 Let's visualize the mysterious dataset!
# 🎯 MYSTERIOUS DATASET ANALYSIS:
# ...
# 📊 Total Data Points: 200
# 📈 X Range: [0.00, 12.57]
# 📈 Y Range: [-2.32, 2.20]
# 📊 Mean Y Value: -0.031
# 📊 Standard Deviation: 0.956
# 🎨 Data appears to have: Low variability
#
# 🌟 **Artistic Observations:**
#    🎨 The data shows a clear pattern with some noise
#    📊 The distribution appears to be centered around -0.03
#    🎯 There might be an underlying function hidden in this data
#    🚨 The noise level suggests we need to be careful about overfitting
#
# 🎪 **Next Steps:**
#    🧮 We'll fit polynomials of different degrees to this data
#    📊 We'll calculate R² scores for each model
#    🎯 We'll determine which model best captures the true pattern
#    🚨 We'll watch out for the overfitting trap!
#
# 🌟 Canvas ready! Time to create our polynomial masterpieces! 🌟

# %%
# 🎨 Creating Polynomial Masterpieces: The Art of Data Fitting! 🎨
print("🎨 Creating our polynomial masterpieces...")
print("🖌️ Let's fit polynomials of different degrees to our mysterious data!")

# 🎯 Define our artistic polynomial function
def f_hat(x, w):
    """
    🎨 Artistic Polynomial Function Creator
    
    Parameters:
    -----------
    x : array-like
        Input values
    w : array-like
        Polynomial coefficients
        
    Returns:
    --------
    array-like
        Polynomial function values
    """
    # Use numpy's polyval for reliable polynomial evaluation
    return np.polyval(w, x)

# 🎪 Define our polynomial degrees for artistic experimentation
poly_order = [1, 3, 5, 10, 25]
print(f"🎯 Polynomial Degrees to Test: {poly_order}")

# 🎨 Create our artistic masterpieces
print(f"\n🎨 Creating Polynomial Masterpieces...")
print("="*60)

w = []  # Store coefficients
y_hat = []  # Store fitted values
r = []  # Store R² values

for i, dim in enumerate(poly_order):
    print(f"🎨 Creating Degree {dim} Masterpiece...")
    
    # Fit the polynomial
    w_temp = np.polyfit(x, my_signal, dim)
    w.append(w_temp)
    
    # Generate fitted values
    y_hat.append(f_hat(x, w_temp))
    
    # Calculate R² score
    slope, intercept, r_value, p_value, std_err = linregress(my_signal, y_hat[-1])
    r.append(r_value)
    
    print(f"   📊 R² Score: {r_value:.4f}")
    print(f"   🎯 Model Quality: {'Excellent' if r_value > 0.9 else 'Good' if r_value > 0.7 else 'Fair' if r_value > 0.5 else 'Poor'}")

# 🎨 Create a spectacular visualization of all our masterpieces
fig, axes = plt.subplots(1, 2, figsize=(16, 8))
fig.suptitle('🎨 The Data Fitting Art Gallery: Polynomial Masterpieces 🎨', 
             fontsize=18, fontweight='bold', y=0.98)

# Plot 1: All polynomial fits on one canvas
axes[0].scatter(x, my_signal, c=art_colors[0], alpha=0.6, s=30, label='Original Data', zorder=5)

for i, (degree, fitted_values, r_score) in enumerate(zip(poly_order, y_hat, r)):
    color_idx = (i + 1) % len(art_colors)  # Use modulo to cycle through colors
    axes[0].plot(x, fitted_values, color=art_colors[color_idx], linewidth=2.5, 
                   label=f'Degree {degree} (R² = {r_score:.4f})', alpha=0.8)

axes[0].set_xlabel('X Values', fontsize=14, fontweight='bold')
axes[0].set_ylabel('f(x) Values', fontsize=14, fontweight='bold')
axes[0].set_title('🎨 All Polynomial Masterpieces 🎨', fontsize=16, fontweight='bold')
axes[0].legend(fontsize=10, loc='upper right')
axes[0].grid(True, alpha=0.3)
axes[0].set_facecolor('#f8f9fa')

# Plot 2: R² scores comparison
degrees_str = [f'Degree {d}' for d in poly_order]
bar_colors = [art_colors[i % len(art_colors)] for i in range(len(poly_order))]
bars = axes[1].bar(degrees_str, r, color=bar_colors, alpha=0.8, edgecolor='white', linewidth=2)
axes[1].set_xlabel('Polynomial Degree', fontsize=14, fontweight='bold')
axes[1].set_ylabel('R² Score', fontsize=14, fontweight='bold')
axes[1].set_title('📊 R² Scores: The Art Critics\' Ratings 📊', fontsize=16, fontweight='bold')
axes[1].grid(True, alpha=0.3)
axes[1].set_facecolor('#f8f9fa')

# Add value labels on bars
for bar, score in zip(bars, r):
    height = bar.get_height()
    axes[1].text(bar.get_x() + bar.get_width()/2., height + 0.01,
                   f'{score:.4f}', ha='center', va='bottom', fontsize=11, fontweight='bold')

plt.tight_layout()
plt.show()

# 🎯 Summary statistics
best_model_idx = np.argmax(r)
best_degree = poly_order[best_model_idx]
best_r2 = r[best_model_idx]

print(f"\n🎯 POLYNOMIAL MASTERPIECE SUMMARY:")
print("="*60)
print(f"📊 Models Created: {len(poly_order)}")
print(f"🎯 Degrees Tested: {poly_order}")
print(f"📈 R² Scores: {[f'{score:.4f}' for score in r]}")

print(f"\n🏆 **Best Performing Model:**")
print(f"   🎨 Degree: {best_degree}")
print(f"   📊 R² Score: {best_r2:.4f}")
print(f"   🎯 Quality Rating: {'Excellent' if best_r2 > 0.9 else 'Good' if best_r2 > 0.7 else 'Fair' if best_r2 > 0.5 else 'Poor'}")

print(f"\n🌟 **Artistic Observations:**")
print(f"   📈 R² scores range from {min(r):.4f} to {max(r):.4f}")
print(f"   🎯 {'Higher degree models generally perform better' if max(r) > min(r) else 'All models perform similarly'}")
print(f"   🚨 {'Warning: Very high R² scores might indicate overfitting!' if max(r) > 0.95 else 'R² scores appear reasonable'}")

print(f"\n🎪 **The Big Question:**")
print(f"   🤔 Is the model with the highest R² score truly the best?")
print(f"   🚨 Or is it memorizing noise instead of learning the true pattern?")
print(f"   🎯 Only the next challenge will reveal the truth!")

# 🎯 Analysis and conclusions
print(f"\n🎯 POLYNOMIAL MASTERPIECE ANALYSIS:")
print("="*60)
print(f"📊 Total Models Created: {len(poly_order)}")
print(f"🎯 Degrees Tested: {poly_order}")
print(f"📈 R² Scores: {[f'{score:.4f}' for score in r]}")

print(f"\n🏆 **Best Performing Model:**")
print(f"   🎨 Degree: {best_degree}")
print(f"   📊 R² Score: {best_r2:.4f}")
print(f"   🎯 Quality Rating: {'Excellent' if best_r2 > 0.9 else 'Good' if best_r2 > 0.7 else 'Fair' if best_r2 > 0.5 else 'Poor'}")

print(f"\n🌟 **Artistic Observations:**")
print(f"   📈 R² scores range from {min(r):.4f} to {max(r):.4f}")
print(f"   🎯 {'Higher degree models generally perform better' if max(r) > min(r) else 'All models perform similarly'}")
print(f"   🚨 {'Warning: Very high R² scores might indicate overfitting!' if max(r) > 0.95 else 'R² scores appear reasonable'}")

print(f"\n🎪 **The Big Question:**")
print(f"   🤔 Is the model with the highest R² score truly the best?")
print(f"   🚨 Or is it memorizing noise instead of learning the true pattern?")
print(f"   🎯 Only the next challenge will reveal the truth!")

print("\n🌟 Polynomial masterpieces complete! Ready for the truth reveal! 🌟")
# Out:
# 🎨 Creating our polynomial masterpieces...
# 🖌️ Let's fit polynomials of different degrees to our mysterious data!
# 🎯 Polynomial Degrees to Test: [1, 3, 5, 10, 25]
#
# 🎨 Creating Polynomial Masterpieces...
# ...
# 🎨 Creating Degree 1 Masterpiece...
#    📊 R² Score: 0.1382
#    🎯 Model Quality: Poor
# 🎨 Creating Degree 3 Masterpiece...
#    📊 R² Score: 0.3274
#    🎯 Model Quality: Poor
# 🎨 Creating Degree 5 Masterpiece...
#    📊 R² Score: 0.3394
#    🎯 Model Quality: Poor
# 🎨 Creating Degree 10 Masterpiece...
#    📊 R² Score: 0.6981
#    🎯 Model Quality: Fair
# 🎨 Creating Degree 25 Masterpiece...
#    📊 R² Score: 0.7189
#    🎯 Model Quality: Good
# 🎯 POLYNOMIAL MASTERPIECE SUMMARY:
# ...
# 📊 Models Created: 5
# 🎯 Degrees Tested: [1, 3, 5, 10, 25]
# 📈 R² Scores: ['0.1382', '0.3274', '0.3394', '0.6981', '0.7189']
#
# 🏆 **Best Performing Model:**
#    🎨 Degree: 25
#    📊 R² Score: 0.7189
#    🎯 Quality Rating: Good
#
# 🌟 **Artistic Observations:**
#    📈 R² scores range from 0.1382 to 0.7189
# ...

# %% [markdown]
# # 🌟 Challenge 2: The Truth Revealed - The Overfitting Illusion! 🌟
#
# ## 🎯 The Moment of Truth Challenge! 🎯
#
# Welcome to the **Truth Revealed** section of our Data Fitting Art Gallery! 🎨 The time has come to lift the veil of perception and discover the true nature of our mysterious dataset. Prepare yourself for a revelation that will forever change how you think about model selection!
#
# ### 🎪 The Shocking Truth:
#
# #### 🌟 **The Hidden Reality:**
# Our mysterious dataset was **NOT** what it appeared to be! Behind the veil of noise lies the true function:
# $$f(x) = \sin(1.5x)$$
#
# The data you've been analyzing was created by adding Gaussian noise $\mathcal{N}(0, 0.75)$ to this beautiful sinusoidal function. This is a perfect example of how **real-world data** often contains noise that obscures the true underlying pattern.
#
# #### 🚨 **The Overfitting Trap:**
# Now we'll discover the **overfitting illusion** - when models with the highest R² scores on training data actually perform **worse** on the true underlying function. This is one of the most important lessons in machine learning and data science!
#
# ### 🎪 Your Mission:
#
# 1. **🌟 Reveal the True Function**: Plot the actual $f(x) = \sin(1.5x)$ alongside all our polynomial models
# 2. **📊 Calculate True R² Scores**: Compute R² values between our models and the **actual** function (not the noisy data)
# 3. **🎯 Identify the Best Model**: Determine which polynomial degree truly captures the underlying pattern
# 4. **🚨 Expose the Overfitting**: Compare training R² vs true R² scores to reveal the overfitting trap
# 5. **🎨 Create Visual Evidence**: Generate compelling visualizations that tell the complete story
#
# ### 🌟 **Key Questions to Answer:**
# - Which model has the highest R² score on the **true** function?
# - How do the training R² scores compare to the true R² scores?
# - Which model best balances complexity and generalization?
# - What does this teach us about model selection in practice?
#
# ### 🎪 **The Overfitting Lesson:**
# > **⚠️ Critical Insight**: A model that perfectly fits noisy training data might be **memorizing the noise** rather than learning the true pattern. This is why we need validation techniques and why the highest R² score isn't always the best choice!
#
# ### 🌟 **Real-World Applications:**
# - **🎨 Data Science**: Avoiding overfitting in predictive models
# - **📊 Machine Learning**: Understanding bias-variance tradeoff
# - **🚨 Business Analytics**: Making models that work on new data
# - **🌟 Scientific Research**: Finding the right level of model complexity
#
# Ready to discover the truth behind the overfitting illusion? 🚀

# %%
# 🌟 The Truth Revealed: Exposing the Overfitting Illusion! 🌟
print("🌟 The moment of truth has arrived!")
print("🎯 Let's reveal the true function and expose the overfitting trap!")

# 🌟 Define the true underlying function
def funct(x):
    """
    🌟 The True Underlying Function
    
    Parameters:
    -----------
    x : array-like
        Input values
        
    Returns:
    --------
    array-like
        True function values: sin(1.5x)
    """
    signal = np.sin(1.5 * x)
    return signal

# 🎯 Calculate the true function values
true_function = funct(x)

# 📊 Calculate R² scores between our models and the TRUE function
print(f"\n📊 Calculating True R² Scores...")
print("="*60)

r_true = []
for i, (degree, fitted_values) in enumerate(zip(poly_order, y_hat)):
    slope, intercept, r_value, p_value, std_err = linregress(true_function, fitted_values)
    r_true.append(r_value)
    print(f"🎨 Degree {degree}: True R² = {r_value:.4f}")

# 🎨 Create a spectacular truth-revealing visualization
fig, axes = plt.subplots(1, 2, figsize=(16, 8))
fig.suptitle('🌟 The Truth Revealed: Exposing the Overfitting Illusion! 🌟', 
             fontsize=18, fontweight='bold', y=0.98)

# Plot 1: True function vs all models
axes[0].plot(x, true_function, color=art_colors[0], linewidth=4, label='True Function: sin(1.5x)', alpha=0.9)
axes[0].scatter(x, my_signal, c=art_colors[1], alpha=0.4, s=20, label='Noisy Data', zorder=5)

for i, (degree, fitted_values, true_r2) in enumerate(zip(poly_order, y_hat, r_true)):
    color_idx = (i + 2) % len(art_colors)  # Use modulo to cycle through colors
    axes[0].plot(x, fitted_values, color=art_colors[color_idx], linewidth=2, 
                   label=f'Degree {degree} (True R² = {true_r2:.4f})', alpha=0.7)

axes[0].set_xlabel('X Values', fontsize=14, fontweight='bold')
axes[0].set_ylabel('f(x) Values', fontsize=14, fontweight='bold')
axes[0].set_title('🌟 True Function vs All Models 🌟', fontsize=16, fontweight='bold')
axes[0].legend(fontsize=9, loc='upper right')
axes[0].grid(True, alpha=0.3)
axes[0].set_facecolor('#f8f9fa')

# Plot 2: Training R² vs True R² comparison
degrees_str = [f'Degree {d}' for d in poly_order]
x_pos = np.arange(len(degrees_str))
width = 0.35

bars1 = axes[1].bar(x_pos - width/2, r, width, label='Training R²', color=art_colors[2], alpha=0.8)
bars2 = axes[1].bar(x_pos + width/2, r_true, width, label='True R²', color=art_colors[3], alpha=0.8)

axes[1].set_xlabel('Polynomial Degree', fontsize=14, fontweight='bold')
axes[1].set_ylabel('R² Score', fontsize=14, fontweight='bold')
axes[1].set_title('📊 Training R² vs True R²: The Overfitting Trap! 📊', fontsize=16, fontweight='bold')
axes[1].set_xticks(x_pos)
axes[1].set_xticklabels(degrees_str)
axes[1].legend(fontsize=12)
axes[1].grid(True, alpha=0.3)
axes[1].set_facecolor('#f8f9fa')

# Add value labels
for bar, score in zip(bars1, r):
    height = bar.get_height()
    axes[1].text(bar.get_x() + bar.get_width()/2., height + 0.01,
                   f'{score:.3f}', ha='center', va='bottom', fontsize=10)
for bar, score in zip(bars2, r_true):
    height = bar.get_height()
    axes[1].text(bar.get_x() + bar.get_width()/2., height + 0.01,
                   f'{score:.3f}', ha='center', va='bottom', fontsize=10)

plt.tight_layout()
plt.show()

# 🎯 Overfitting analysis
overfitting_gap = [train - true for train, true in zip(r, r_true)]
best_training_idx = np.argmax(r)
best_true_idx = np.argmax(r_true)
best_training_degree = poly_order[best_training_idx]
best_true_degree = poly_order[best_true_idx]
best_true_r2 = max(r_true)

print(f"\n🌟 TRUTH REVEALED: OVERFITTING ANALYSIS")
print("="*70)

print(f"\n📊 **True Function Analysis:**")
print(f"   🌟 True Function: f(x) = sin(1.5x)")
print(f"   📊 Noise Level: Gaussian N(0, 0.75)")
print(f"   🎯 Data Points: {len(x)}")

print(f"\n🏆 **Best Model Identification:**")
print(f"   📊 Training R² Best: Degree {best_training_degree} (R² = {r[best_training_idx]:.4f})")
print(f"   🌟 True R² Best: Degree {best_true_degree} (R² = {best_true_r2:.4f})")
print(f"   🎯 {'Same model is best for both!' if best_training_degree == best_true_degree else 'Different models are best!'}")

print(f"\n🚨 **Overfitting Analysis:**")
print(f"   📈 Overfitting Gaps: {[f'{gap:.4f}' for gap in overfitting_gap]}")
print(f"   🚨 Most Overfitted: Degree {poly_order[np.argmax(overfitting_gap)]} (Gap = {max(overfitting_gap):.4f})")
print(f"   🌟 Least Overfitted: Degree {poly_order[np.argmin(overfitting_gap)]} (Gap = {min(overfitting_gap):.4f})")

print(f"\n🌟 **Key Insights:**")
print(f"   🎯 {'Higher degree models show more overfitting' if max(overfitting_gap) > 0.1 else 'Overfitting is minimal across all models'}")
print(f"   📊 Training R² scores are {'significantly higher' if max(r) - max(r_true) > 0.1 else 'similar to'} true R² scores")
print(f"   🚨 {'Warning: High overfitting detected!' if max(overfitting_gap) > 0.2 else 'Models appear to generalize well'}")

print(f"\n🎪 **The Overfitting Lesson:**")
print(f"   🌟 The model with the highest training R² is NOT always the best choice")
print(f"   📊 True performance on unseen data is what matters most")
print(f"   🚨 Validation techniques are essential for model selection")
print(f"   🎯 Balance between bias and variance is crucial")

# 🎯 Comprehensive analysis and conclusions
print(f"\n🌟 TRUTH REVEALED: COMPREHENSIVE ANALYSIS")
print("="*70)

print(f"\n📊 **True Function Analysis:**")
print(f"   🌟 True Function: f(x) = sin(1.5x)")
print(f"   📊 Noise Level: Gaussian N(0, 0.75)")
print(f"   🎯 Data Points: {len(x)}")

print(f"\n🏆 **Best Model Identification:**")
print(f"   📊 Training R² Best: Degree {best_training_degree} (R² = {r[best_training_idx]:.4f})")
print(f"   🌟 True R² Best: Degree {best_true_degree} (R² = {best_true_r2:.4f})")
print(f"   🎯 {'Same model is best for both!' if best_training_degree == best_true_degree else 'Different models are best!'}")

print(f"\n🚨 **Overfitting Analysis:**")
print(f"   📈 Overfitting Gaps: {[f'{gap:.4f}' for gap in overfitting_gap]}")
print(f"   🚨 Most Overfitted: Degree {poly_order[np.argmax(overfitting_gap)]} (Gap = {max(overfitting_gap):.4f})")
print(f"   🌟 Least Overfitted: Degree {poly_order[np.argmin(overfitting_gap)]} (Gap = {min(overfitting_gap):.4f})")

print(f"\n🌟 **Key Insights:**")
print(f"   🎯 {'Higher degree models show more overfitting' if max(overfitting_gap) > 0.1 else 'Overfitting is minimal across all models'}")
print(f"   📊 Training R² scores are {'significantly higher' if max(r) - max(r_true) > 0.1 else 'similar to'} true R² scores")
print(f"   🚨 {'Warning: High overfitting detected!' if max(overfitting_gap) > 0.2 else 'Models appear to generalize well'}")

print(f"\n🎪 **The Overfitting Lesson:**")
print(f"   🌟 The model with the highest training R² is NOT always the best choice")
print(f"   📊 True performance on unseen data is what matters most")
print(f"   🚨 Validation techniques are essential for model selection")
print(f"   🎯 Balance between bias and variance is crucial")

print("\n🌟 Truth revealed! The overfitting illusion has been exposed! 🌟")
# Out:
# 🌟 The moment of truth has arrived!
# 🎯 Let's reveal the true function and expose the overfitting trap!
#
# 📊 Calculating True R² Scores...
# ...
# 🎨 Degree 1: True R² = 0.2578
# 🎨 Degree 3: True R² = 0.3968
# 🎨 Degree 5: True R² = 0.3693
# 🎨 Degree 10: True R² = 0.9595
# 🎨 Degree 25: True R² = 0.9558
# 🌟 TRUTH REVEALED: OVERFITTING ANALYSIS
# ...
#
# 📊 **True Function Analysis:**
#    🌟 True Function: f(x) = sin(1.5x)
#    📊 Noise Level: Gaussian N(0, 0.75)
#    🎯 Data Points: 200
#
# 🏆 **Best Model Identification:**
#    📊 Training R² Best: Degree 25 (R² = 0.7189)
#    🌟 True R² Best: Degree 10 (R² = 0.9595)
#    🎯 Different models are best!
#
# 🚨 **Overfitting Analysis:**
#    📈 Overfitting Gaps: ['-0.1195', '-0.0694', '-0.0300', '-0.2614', '-0.2369']
#    🚨 Most Overfitted: Degree 5 (Gap = -0.0300)
#    🌟 Least Overfitted: Degree 10 (Gap = -0.2614)
#
# 🌟 **Key Insights:**
#    🎯 Overfitting is minimal across all models
#    📊 Training R² scores are similar to true R² scores
# ...

# %% [markdown]
# # 🎓 Tutorial 9 Complete: Summary of Achievements! 🎓
#
# ## 🌟 What We've Accomplished:
#
# ### 🎨 **Challenge 1: The Data Fitting Art Gallery**
# - **🎨 Mastered Polynomial Regression**: Created models of degrees 1, 3, 5, 10, and 25
# - **📊 Calculated R² Scores**: Evaluated model performance on training data
# - **🎨 Created Beautiful Visualizations**: Developed comprehensive plots showing all polynomial fits
# - **🎯 Identified Best Training Model**: Found the model with highest training R² score
#
# ### 🌟 **Challenge 2: The Truth Revealed - Overfitting Exposed**
# - **🌟 Revealed True Function**: Discovered the underlying sin(1.5x) pattern
# - **📊 Calculated True R² Scores**: Evaluated models against the actual function
# - **🚨 Exposed Overfitting**: Compared training vs true performance to reveal the trap
# - **🎯 Identified Best True Model**: Found the model that best captures the underlying pattern
#
# ## 🎯 Key Learning Outcomes Achieved:
#
# 1. **🎨 Data Fitting Mastery**:
#    - Polynomial regression with different degrees
#    - R² score calculation and interpretation
#    - Model complexity vs performance analysis
#
# 2. **🚨 Overfitting Recognition**:
#    - Understanding the difference between training and true performance
#    - Identifying when models memorize noise vs learn patterns
#    - Recognizing the bias-variance tradeoff
#
# 3. **🎨 Visualization Expertise**:
#    - Multi-panel plots showing model comparisons
#    - Training vs true R² score comparisons
#    - Overfitting gap analysis
#
# 4. **🌟 Model Selection Wisdom**:
#    - Choosing the right level of complexity
#    - Balancing underfitting vs overfitting
#    - Understanding the Goldilocks principle
#
# 5. **🧮 Statistical Software Proficiency**:
#    - NumPy for polynomial fitting
#    - Matplotlib for visualization
#    - Scipy for statistical calculations
#
# ## 🎪 The Overfitting Lesson:
#
# ### 🌟 **Key Insights:**
# - **🎯 The Highest R² Score Isn't Always Best**: Models with perfect training performance might be overfitting
# - **📊 True Performance Matters**: What counts is how well the model works on new, unseen data
# - **🚨 Validation is Essential**: Always validate models on independent datasets
# - **🌟 Balance is Key**: Find the sweet spot between underfitting and overfitting
#
# ### 🎨 **Real-World Applications:**
# - **📊 Machine Learning**: Avoiding overfitting in predictive models
# - **🎯 Data Science**: Building models that generalize well
# - **🚨 Business Analytics**: Making models that work in practice
# - **🌟 Scientific Research**: Understanding model complexity tradeoffs
#
# ## 🎪 Next Steps in Your Statistical Journey:
#
# - **Advanced Topics**: Cross-validation, regularization, ensemble methods
# - **Machine Learning**: Applied ML with proper validation techniques
# - **Real-World Projects**: Apply these skills to your own datasets
#
# ## 🌟 Congratulations!
#
# You've successfully completed **Tutorial 9: R-Squared and Data Fitting** and are now equipped with powerful insights for:
# - **🎨 Model Selection**: Choosing the right level of complexity
# - **🚨 Overfitting Prevention**: Recognizing and avoiding the overfitting trap
# - **📊 Performance Evaluation**: Understanding the difference between training and true performance
# - **🌟 Statistical Wisdom**: Balancing bias and variance for optimal results
#
# **🎨 You're now a data fitting artist who understands the delicate balance between creativity and overfitting! 🎨**
